# %%
import pandas as pd
path1= "C:\\Users\\sweth\\OneDrive\\Desktop\\HEP_TEST.csv"
# attributes= ['Class', 'AGE', 'SEX', 'STEROID', 'ANTIVIRALS', 'FATIGUE', 'MALAISE', 'ANOREXIA', 
#              'LIVER BIG', 'LIVER FIRM', 'SPLEEN PALPABLE', 'SPIDERS', 'ASCITES', 'VARICES', 
#              'BILIRUBIN', 'ALK PHOSPHATE', 'SGOT', 'ALBUMIN', 'PROTIME', 'HISTOLOGY']
# data= pd.read_csv(path1, names= attributes)
data= pd.read_csv(path1)

# %%
print('the data dimensions are (rows, cols): ', data.shape)
# Out:
# the data dimensions are (rows, cols):  (142, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   class           142 non-null    int64
#  1   age             142 non-null    int64
#  2   sex             142 non-null    int64
#  3   steroid         142 non-null    int64
#  4   antivirals      142 non-null    int64
#  5   fatigue         142 non-null    int64
#  6   malaise         142 non-null    int64
#  7   anorexia        142 non-null    int64
#  8   liver_big       142 non-null    int64
#  9   liver_firm      142 non-null    int64
#  10  spleen_palable  142 non-null    int64
#  11  spiders         142 non-null    int64
#  12  ascites         142 non-null    int64
#  13  varices         142 non-null    int64
#  14  bilirubin       142 non-null    float64
#  15  alk_phosphate   142 non-null    int64
#  16  sgot            142 non-null    int64
# ...

# %%
data.columns= data.columns.str.upper().str.replace('_', ' ').str.replace('CLASS', 'Class').str.replace('PALABLE', 'PALPABLE')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Class            142 non-null    int64
#  1   AGE              142 non-null    int64
#  2   SEX              142 non-null    int64
#  3   STEROID          142 non-null    int64
#  4   ANTIVIRALS       142 non-null    int64
#  5   FATIGUE          142 non-null    int64
#  6   MALAISE          142 non-null    int64
#  7   ANOREXIA         142 non-null    int64
#  8   LIVER BIG        142 non-null    int64
#  9   LIVER FIRM       142 non-null    int64
#  10  SPLEEN PALPABLE  142 non-null    int64
#  11  SPIDERS          142 non-null    int64
#  12  ASCITES          142 non-null    int64
#  13  VARICES          142 non-null    int64
#  14  BILIRUBIN        142 non-null    float64
#  15  ALK PHOSPHATE    142 non-null    int64
#  16  SGOT             142 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# Class              0
# AGE                0
# SEX                0
# STEROID            0
# ANTIVIRALS         0
# FATIGUE            0
# MALAISE            0
# ANOREXIA           0
# LIVER BIG          0
# LIVER FIRM         0
# SPLEEN PALPABLE    0
# SPIDERS            0
# ASCITES            0
# VARICES            0
# BILIRUBIN          0
# ALK PHOSPHATE      0
# SGOT               0
# ALBUMIN            0
# PROTIME            0
# HISTOLOGY          0
# dtype: int64

# %%
data.head(5)
# Out:
#    Class  AGE  SEX  STEROID  ANTIVIRALS  FATIGUE  MALAISE  ANOREXIA  \
# 0      2   30    2        1           2        2        2         2
# 1      2   50    1        1           2        1        2         2
# 2      2   78    1        2           2        1        2         2
# 3      2   34    1        2           2        2        2         2
# 4      2   34    1        2           2        2        2         2
#
#    LIVER BIG  LIVER FIRM  SPLEEN PALPABLE  SPIDERS  ASCITES  VARICES  \
# 0          1           2                2        2        2        2
# 1          1           2                2        2        2        2
# 2          2           2                2        2        2        2
# 3          2           2                2        2        2        2
# 4          2           2                2        2        2        2
#
#    BILIRUBIN  ALK PHOSPHATE  SGOT  ALBUMIN  PROTIME  HISTOLOGY
# 0        1.0             85    18      4.0       61          1
# ...

# %%
data.replace('?', pd.NA, inplace=True)

# %%
data.isnull().sum()
# Out:
# Class              0
# AGE                0
# SEX                0
# STEROID            0
# ANTIVIRALS         0
# FATIGUE            0
# MALAISE            0
# ANOREXIA           0
# LIVER BIG          0
# LIVER FIRM         0
# SPLEEN PALPABLE    0
# SPIDERS            0
# ASCITES            0
# VARICES            0
# BILIRUBIN          0
# ALK PHOSPHATE      0
# SGOT               0
# ALBUMIN            0
# PROTIME            0
# HISTOLOGY          0
# dtype: int64

# %%
data= data.dropna()

# %%
data= data.apply(pd.to_numeric)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix= data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=2)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
data= pd.DataFrame(data= data.drop(columns=['SGOT', 'ANTIVIRALS', 'LIVER FIRM']))

# %%
data['Class'].value_counts()
# Out:
# 2    116
# 1     26
# Name: Class, dtype: int64

# %%
data.to_csv('HEP_TEST_ASAP.csv', index= False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Class            142 non-null    int64
#  1   AGE              142 non-null    int64
#  2   SEX              142 non-null    int64
#  3   STEROID          142 non-null    int64
#  4   FATIGUE          142 non-null    int64
#  5   MALAISE          142 non-null    int64
#  6   ANOREXIA         142 non-null    int64
#  7   LIVER BIG        142 non-null    int64
#  8   SPLEEN PALPABLE  142 non-null    int64
#  9   SPIDERS          142 non-null    int64
#  10  ASCITES          142 non-null    int64
#  11  VARICES          142 non-null    int64
#  12  BILIRUBIN        142 non-null    float64
#  13  ALK PHOSPHATE    142 non-null    int64
#  14  ALBUMIN          142 non-null    float64
#  15  PROTIME          142 non-null    int64
#  16  HISTOLOGY        142 non-null    int64
# ...
